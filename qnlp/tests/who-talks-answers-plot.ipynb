# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def m(a):
    return np.floor(np.pi/(4*theta(a)))

def theta(a):
    return np.arcsin(np.sqrt(a))

# %%
data = np.loadtxt('data/2021-11-29--15:12:50-who-talks-answers.txt').transpose()
plt.plot(data[0], data[1])

# %%
m, prob = np.loadtxt('data/2021-11-29--15:42:31-who-talks-answers.txt').transpose()
a = prob[0]

plt.plot(m, prob)
plt.plot(m, np.sin((2*m+1)*theta(a))**2)

# %%
m, prob = np.loadtxt('data/2021-11-30--16:36:40-who-talks-answers.txt').transpose()
a = prob[0]

plt.plot(m, prob)
plt.plot(m, np.sin((2*m+1)*theta(a))**2)
