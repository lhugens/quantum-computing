# %% [markdown]
# # Imports

# %%
# To install Qiskit, uncomment and run the line below
# !pip install -r requirements.txt --quiet

# If you haven't used your IBMQ account yet, load it using your TOKEN:
# IBMQ.save_account(TOKEN)

# Qiskit imports
import qiskit
from qiskit import IBMQ, Aer
from qiskit.providers.aer import QasmSimulator
import qiskit.tools.jupyter

# %% [markdown]
# # Load provider and backend

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
backend_sim = Aer.get_backend('qasm_simulator')
backend_qc = provider.get_backend('ibmq_manila')
backend_qc_sim = QasmSimulator.from_backend(backend_qc)
# Out:
# ibmqfactory.load_account:WARNING:2021-12-27 17:12:27,524: Credentials are already in use. The existing account in the session will be replaced.

# %%
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.19.1</td></tr><tr><td><code>qiskit-aer</code></td><td>0.10.1</td></tr><tr><td><code>qiskit-ignis</code></td><td>0.7.0</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.18.3</td></tr><tr><td><code>qiskit</code></td><td>0.34.0</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.9.9</td></tr><tr><td>Python compiler</td><td>GCC 11.1.0</td></tr><tr><td>Python build</td><td>main, Dec 22 2021 12:20:33</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>15.44140625</td></tr><tr><td colspan='2'>Mon Dec 27 17:04:12 2021 +01</td></tr></table>
